# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
from time import time
from tqdm import tqdm
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.manifold import TSNE
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show, output_file, output_notebook
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label, HoverTool

# %%
#np.save('plot', Y)
Y=np.load('../data/raw/plot.npy')
output_notebook()

N = 4000
x, y = Y[:, 0], Y[:, 1]

#source = ColumnDataSource(data=pca_df)

hover = HoverTool(tooltips=[
#    ("words", "@words"),
    ("(x,y)", "($x, $y)"),
])

p = figure(plot_width=500, plot_height=500, 
           title='Visualization through PCA')

p.scatter(x=x, y=y, size=10, fill_alpha=0.6, marker='triangle',)# color='orange')

p.text(x, y, alpha=0.6,)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="543375ad-2872-4d65-b185-36277f70c242">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8286496d-7f9a-4694-bcfe-c11e900b8c3e"></div>
# </div>
