# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd

datapath = '/Users/yiru/projects/Fashion_Project_18/'

# %%
df = pd.read_hdf(datapath+'data/modified/df.h5', 'table')
nap_labelled = pd.read_hdf(datapath+'notebooks/nap_labelled_updated_pid_label.h5', 'table')
#df.drop(columns=['style'], inplace=True)

# %%
nap_labelled = pd.read_hdf(datapath+'notebooks/nap_labelled_updated_pid_label.h5', 'table')
nap_labelled
# Out:
#                     product_id                                    label
# 0     5b013e8c4500d65c4d2fa41b                               [romantic]
# 1     5b013e8d4500d65c4d2fa425                                 [street]
# 2     5b013e8e4500d65c4d2fa43d                      [classic, romantic]
# 3     5b013e8e4500d65c4d2fa445                  [classic, minimalistic]
# 4     5b013e8e4500d65c4d2fa446                                 [gothic]
# 5     5b013e8f4500d65c4d2fa45a                             [athleisure]
# 6     5b013e8f4500d65c4d2fa45b                    [athleisure, classic]
# 7     5b013e8f4500d65c4d2fa460                   [punk, edgy, romantic]
# 8     5b013e8f4500d65c4d2fa461                       [classic, vintage]
# 9     5b013e904500d65c4d2fa47c                         [romantic, glam]
# 10    5b013e904500d65c4d2fa487               [edgy, minimalistic, chic]
# 11    5b013e904500d65c4d2fa488                     [classic, sartorial]
# ...

# %%
df_labelled = pd.merge(df, nap_labelled, on='product_id', how='left')

# %%
df[df['label'].notnull()]
# Out:
#                       product_id designer_original_name  \
# 956146  5b013e8c4500d65c4d2fa41b              Valentino
# 956156  5b013e8d4500d65c4d2fa425              Valentino
# 956177  5b013e8e4500d65c4d2fa43d              Valentino
# 956183  5b013e8e4500d65c4d2fa445               Burberry
# 956184  5b013e8e4500d65c4d2fa446      Alexander McQueen
# 956201  5b013e8f4500d65c4d2fa45a              Valentino
# 956202  5b013e8f4500d65c4d2fa45b               Burberry
# 956207  5b013e8f4500d65c4d2fa460      Alexander McQueen
# 956208  5b013e8f4500d65c4d2fa461               Burberry
# 956230  5b013e904500d65c4d2fa47c                  Erdem
# 956242  5b013e904500d65c4d2fa488                Versace
# 956259  5b013e914500d65c4d2fa499      Alexander McQueen
# 956262  5b013e914500d65c4d2fa49c      Alexander McQueen
# 956302  5b013e934500d65c4d2fa4c4              Valentino
# 956308  5b013e934500d65c4d2fa4ca              Valentino
# 956331  5b013e944500d65c4d2fa4e5               Burberry
# ...

# %%
df_labelled[df_labelled['label'].notnull()].sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/fashion_project/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-8d2eb29ebeb4> in <module>()
# ...

# %%
df_labelled.to_hdf(datapath+'df.h5', 'table')
# Out:
# /home/ubuntu/.virtualenvs/hana/lib/python3.6/site-packages/pandas/core/generic.py:1993: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['product_id', 'designer_original_name', 'product_name', 'comb_desc', 'From', 'label']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
