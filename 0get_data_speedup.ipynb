# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 13 18:16:03 2015

@author: Himanshu
"""

import json
import urllib
import asyncio
import aiohttp
import pandas as pd
import csv
import time
import requests

from collections import OrderedDict
from urllib.request import urlopen

# %%
product_list=['Product ID','Name','Price','Currency','Retailer ID',
                    'Retailer Name','Brand ID','Brand Name','Description',
                    'image_small','image_XLarge','image_Medium','image_Large','image_IPhoneSmall',
                    'image_Best','image_Original','image_IPhone',
                    'Extract Date','Last Modified','Colors','Sizes','Categories']

# %%
""" Creating master product list """
def get_brands_from_api():
    url = 'http://api.shopstyle.com/api/v2/brands?pid=uid5281-8673591-38'
    response = requests.get(url)
    results = response.json()
#     brand_response = urlopen(url)
#     brand_results = brand_response.read().decode('utf8')
#     results = json.loads(brand_results)

    data = results['brands']
    brand_dict = OrderedDict()
    for b in data:
        brand_dict[b['id']] = b['name']
    #brand_dict = list(brand_dict.keys())[:2] ### only two brands at once
    return brand_dict

# %%
brand_lists = get_brands_from_api()
brand_ids=list(brand_lists.keys())

# %%
len(brand_lists)
# Out:
# 8493

# %%
class async_product_scraper:
    """Download product info for brands on shopstyle api"""
    
    def __init__(self):
        pass
        
    async def _fetch(self, url, params, session):
        """
        Params:
            url: str, request url
            session: aiohttp.ClientSession() object
        Returns:
            response : JSON/Python Dict
        """
        
        async with session.get(url, params=params) as response:
            return await response.json()
        
    async def run(self, brandID):
        BASEURL = 'http://api.shopstyle.com/api/v2/products?pid=uid5281-8673591-38&format=json&'
  
        # offset params to get products with offset 0-5000
        offset_params = [{'fl': 'b{}'.format(brandID), 'offset': r, 'limit': 50} for r in range(0,5000,50)]
        async with aiohttp.ClientSession() as session:
            tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session)) 
                     for offset in offset_params]
            return await asyncio.gather(*tasks, return_exceptions=False)

## Multiple brands is slower        
#     async def run(self, brandIDs):
#         BASEURL = 'http://api.shopstyle.com/api/v2/products?pid=uid5281-8673591-38&format=json&'
#         # offset params to get products with offset 0-5000
#         offset_params = [[{'fl': 'b{}'.format(brandID), 'offset': r, 'limit': 50} for r in range(0,5000,50)] for brandID in brandIDs]
#         offset_params = [item for sublist in offset_params for item in sublist]
#         async with aiohttp.ClientSession() as session:
#             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session)) 
#                      for offset in offset_params]
#             return await asyncio.gather(*tasks, return_exceptions=False)

class product_writer:
    
    def __init__(self, response):
        self.response = response
        
    def product_info_df(self):
        DFS = [pd.DataFrame(r['products']) for r in self.response]
        products_df = pd.concat(DFS,ignore_index=True)
#         product_dict = self.response['products']
#         products_df = pd.DataFrame(product_dict)
        
        # retailer id/name
        retailer_df = products_df['retailer'].apply(pd.Series)[['id', 'name']]
        retailer_df.columns = ['retailer_id', 'retailer_name']
        products_df = pd.concat([products_df.drop(['retailer'], axis=1), retailer_df], axis=1)
        
        # sizes
        products_df.loc[:, 'sizes'] = products_df['sizes'].apply(lambda x: [size['name'] for size in x] if x else '')
        
        # brand id/name
        brand_placeholder = {'id': '', 'name': ''} # placeholder for NaNs
        products_df.loc[:, 'brand'] = products_df['brand'].apply(lambda d: d if isinstance(d, dict) else brand_placeholder)
        brand_df = pd.DataFrame(products_df['brand'].apply(pd.Series))
        brand_df.columns = ['brand_id', 'brand_name']
        products_df = pd.concat([products_df.drop(['brand'], axis=1), brand_df], axis=1)
        
#       image urls
        image_df = products_df['image'].apply(lambda x: pd.Series(x['sizes'])).applymap(lambda y: y['url'])
        products_df = pd.concat([products_df.drop(['image'],axis=1), image_df], axis=1)       
        
        # colors
        products_df.loc[:, 'colors'] = products_df['colors'].apply(lambda x: [color['name'] for color in x] if x else '')
        
        # categories
        products_df.loc[: ,'categories'] = products_df['categories'].apply(lambda x: [category['name'] for category in x] if x else '')
        
        return products_df

# %%
product_scraper = async_product_scraper()

# %%
def downloading(brandID):
        loop = asyncio.get_event_loop()
        future = asyncio.ensure_future(product_scraper.run(brandID))
        loop.run_until_complete(future)
        result = future.result()

        parser = product_writer(result)
        df = parser.product_info_df()
        keep_columns =['id', 'name', 'price', 'currency', 'retailer_id', 'retailer_name',
         'brand_id', 'brand_name', 'description',
         'Small', 'XLarge', 'Medium', 'Large', 'IPhoneSmall', 'Best', 
         'Original', 'IPhone', 'extractDate', 'lastModified', 'colors', 'sizes', 'categories']
        df = df[keep_columns]
        with open('data/products_brand_Apr.csv', 'a') as f:
            writer = csv.writer(f, delimiter=',')
            writer.writerow(product_list)    
            df.to_csv(f,encoding='utf-8',index=False,header=False)
        return df

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[:10]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 3
# Time Used: 6.64926815032959 sec
# Downloading brand 5
# Time Used: 1.039794921875 sec
# Downloading brand 6
# Time Used: 5.293516159057617 sec
# Downloading brand 7
# Time Used: 0.5486218929290771 sec
# Downloading brand 14
# Time Used: 9.613234996795654 sec
# Downloading brand 15
# Time Used: 4.957540988922119 sec
# Downloading brand 16
# Time Used: 0.5401949882507324 sec
# Downloading brand 17
# Time Used: 0.49471092224121094 sec
# Downloading brand 18
# Time Used: 5.850774049758911 sec
# Downloading brand 19
# Time Used: 1.5974528789520264 sec

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[10:100]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 20
# Time Used: 2.694216012954712 sec
# Downloading brand 22
# Time Used: 0.7197179794311523 sec
# Downloading brand 24
# Time Used: 0.5947921276092529 sec
# Downloading brand 25
# Time Used: 1.2949309349060059 sec
# Downloading brand 28
# Time Used: 1.8220739364624023 sec
# Downloading brand 30
# Time Used: 3.614392042160034 sec
# Downloading brand 31
# Time Used: 4.01398491859436 sec
# Downloading brand 33
# Time Used: 1.6735751628875732 sec
# Downloading brand 36
# Time Used: 1.1370611190795898 sec
# Downloading brand 38
# Time Used: 6.737213850021362 sec
# Downloading brand 39
# Time Used: 0.4324679374694824 sec
# Downloading brand 41
# Time Used: 1.6333260536193848 sec
# Downloading brand 42
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-15-b0ed91936b0d> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[22:100]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 42
# Time Used: 0.814511775970459 sec
# Downloading brand 44
# Time Used: 0.7824978828430176 sec
# Downloading brand 46
# Time Used: 3.837007999420166 sec
# Downloading brand 49
# Time Used: 0.7536768913269043 sec
# Downloading brand 51
# Time Used: 6.168938875198364 sec
# Downloading brand 55
# Time Used: 0.8314721584320068 sec
# Downloading brand 56
# Time Used: 0.7674429416656494 sec
# Downloading brand 59
# Time Used: 0.733961820602417 sec
# Downloading brand 60
# Time Used: 0.9114410877227783 sec
# Downloading brand 61
# Time Used: 4.556144952774048 sec
# Downloading brand 63
# Time Used: 2.289518117904663 sec
# Downloading brand 64
# Time Used: 0.4735381603240967 sec
# Downloading brand 65
# Time Used: 6.214260101318359 sec
# Downloading brand 66
# Time Used: 1.0727519989013672 sec
# Downloading brand 69
# Time Used: 0.6294698715209961 sec
# Downloading brand 72
# Time Used: 2.943419933319092 sec
# Downloading brand 73
# Time Used: 0.7468550205230713 sec
# Downloading brand 75
# Time Used: 4.640359878540039 sec
# Downloading brand 76
# Time Used: 0.8187370300292969 sec
# Downloading brand 78
# Time Used: 0.7369849681854248 sec
# Downloading brand 82
# Time Used: 1.061230182647705 sec
# Downloading brand 86
# Time Used: 0.6384730339050293 sec
# Downloading brand 87
# Time Used: 1.5117518901824951 sec
# Downloading brand 90
# Time Used: 2.673891067504883 sec
# Downloading brand 92
# Time Used: 1.597749948501587 sec
# Downloading brand 93
# Time Used: 1.261979103088379 sec
# Downloading brand 95
# Time Used: 0.7482609748840332 sec
# Downloading brand 98
# Time Used: 0.6085450649261475 sec
# Downloading brand 99
# Time Used: 0.5235390663146973 sec
# Downloading brand 102
# Time Used: 2.1754870414733887 sec
# Downloading brand 103
# Time Used: 8.10301685333252 sec
# Downloading brand 104
# Time Used: 2.2567780017852783 sec
# Downloading brand 107
# Time Used: 1.3778650760650635 sec
# Downloading brand 108
# Time Used: 1.5504200458526611 sec
# Downloading brand 109
# Time Used: 1.1991238594055176 sec
# Downloading brand 110
# Time Used: 7.965726852416992 sec
# Downloading brand 111
# Time Used: 1.1643362045288086 sec
# Downloading brand 113
# Time Used: 0.998643159866333 sec
# Downloading brand 114
# Time Used: 1.4261600971221924 sec
# Downloading brand 115
# Time Used: 2.1038200855255127 sec
# Downloading brand 119
# Time Used: 2.567452907562256 sec
# Downloading brand 122
# Time Used: 1.372197151184082 sec
# Downloading brand 124
# Time Used: 2.355372905731201 sec
# Downloading brand 127
# Time Used: 0.49729084968566895 sec
# Downloading brand 128
# Time Used: 0.4070868492126465 sec
# Downloading brand 129
# Time Used: 1.3399510383605957 sec
# Downloading brand 130
# Time Used: 1.933858871459961 sec
# Downloading brand 131
# Time Used: 1.829474925994873 sec
# Downloading brand 135
# Time Used: 0.9933121204376221 sec
# Downloading brand 136
# Time Used: 5.187426805496216 sec
# Downloading brand 138
# Time Used: 0.7012557983398438 sec
# Downloading brand 140
# Time Used: 0.41632795333862305 sec
# Downloading brand 141
# Time Used: 0.9942209720611572 sec
# Downloading brand 142
# Time Used: 7.305171966552734 sec
# Downloading brand 144
# Time Used: 6.266189098358154 sec
# Downloading brand 146
# Time Used: 7.181349992752075 sec
# Downloading brand 148
# Time Used: 2.052075147628784 sec
# Downloading brand 150
# Time Used: 0.5362310409545898 sec
# Downloading brand 151
# Time Used: 1.0900330543518066 sec
# Downloading brand 155
# Time Used: 0.8437838554382324 sec
# Downloading brand 156
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# <ipython-input-51-9054af9702f4> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     237                 # We use the `send` method directly, because coroutines
#     238                 # don't have `__iter__` and `__next__` methods.
# --> 239                 result = coro.send(None)
#     240             else:
#     241                 result = coro.throw(exc)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      15
#      16         async with session.get(url, params=params) as response:
# ---> 17             return await response.json()
#      18
#      19     async def run(self, brandID):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client_reqrep.py in json(self, encoding, loads, content_type)
#     728                     message=('Attempt to decode JSON with '
#     729                              'unexpected mimetype: %s' % ctype),
# --> 730                     headers=self.headers)
#     731
#     732         stripped = self._content.strip()
#
# ClientResponseError: 0, message='Attempt to decode JSON with unexpected mimetype: '

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[82:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 156
# Time Used: 6.242364883422852 sec
# Downloading brand 163
# Time Used: 1.266050100326538 sec
# Downloading brand 164
# Time Used: 0.6422851085662842 sec
# Downloading brand 165
# Time Used: 1.0086939334869385 sec
# Downloading brand 166
# Time Used: 0.5838720798492432 sec
# Downloading brand 167
# Time Used: 2.173578977584839 sec
# Downloading brand 169
# Time Used: 0.9458708763122559 sec
# Downloading brand 170
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-60-54e5fa4aea8c> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[89:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 170
# Time Used: 2.5766029357910156 sec
# Downloading brand 171
# Time Used: 8.368900060653687 sec
# Downloading brand 172
# Time Used: 7.898025035858154 sec
# Downloading brand 173
# Time Used: 7.501443862915039 sec
# Downloading brand 174
# Time Used: 2.991771936416626 sec
# Downloading brand 175
# Time Used: 5.748074054718018 sec
# Downloading brand 177
# Time Used: 1.9318428039550781 sec
# Downloading brand 178
# Time Used: 0.9513850212097168 sec
# Downloading brand 179
# Time Used: 8.788113117218018 sec
# Downloading brand 180
# Time Used: 2.5404059886932373 sec
# Downloading brand 181
# Time Used: 0.48406219482421875 sec
# Downloading brand 183
# Time Used: 1.9030399322509766 sec
# Downloading brand 184
# Time Used: 2.165540933609009 sec
# Downloading brand 185
# Time Used: 1.3743338584899902 sec
# Downloading brand 189
# Time Used: 0.8877639770507812 sec
# Downloading brand 191
# Time Used: 0.5040149688720703 sec
# Downloading brand 192
# Time Used: 6.474982023239136 sec
# Downloading brand 193
# Time Used: 1.1371259689331055 sec
# Downloading brand 194
# Time Used: 1.9297738075256348 sec
# Downloading brand 195
# Time Used: 1.371523141860962 sec
# Downloading brand 197
# Time Used: 5.09154486656189 sec
# Downloading brand 198
# Time Used: 0.5280661582946777 sec
# Downloading brand 201
# Time Used: 0.4607260227203369 sec
# Downloading brand 202
# Time Used: 0.7545688152313232 sec
# Downloading brand 203
# Time Used: 1.1916639804840088 sec
# Downloading brand 206
# Time Used: 0.5207309722900391 sec
# Downloading brand 209
# Time Used: 0.48368215560913086 sec
# Downloading brand 211
# Time Used: 0.7672610282897949 sec
# Downloading brand 214
# Time Used: 0.8321361541748047 sec
# Downloading brand 215
# Time Used: 2.7377710342407227 sec
# Downloading brand 216
# Time Used: 2.0670340061187744 sec
# Downloading brand 217
# Time Used: 0.43260812759399414 sec
# Downloading brand 218
# Time Used: 1.313108205795288 sec
# Downloading brand 220
# Time Used: 0.5360448360443115 sec
# Downloading brand 222
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-62-cb24f502cb75> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[123:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 222
# Time Used: 4.068339109420776 sec
# Downloading brand 223
# Time Used: 1.0415749549865723 sec
# Downloading brand 224
# Time Used: 0.6218488216400146 sec
# Downloading brand 225
# Time Used: 5.546773910522461 sec
# Downloading brand 226
# Time Used: 10.218796014785767 sec
# Downloading brand 227
# Time Used: 5.770864963531494 sec
# Downloading brand 230
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-66-31f185f496bd> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[129:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 230
# Time Used: 10.938329935073853 sec
# Downloading brand 231
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# <ipython-input-68-a5235f82a804> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     237                 # We use the `send` method directly, because coroutines
#     238                 # don't have `__iter__` and `__next__` methods.
# --> 239                 result = coro.send(None)
#     240             else:
#     241                 result = coro.throw(exc)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      15
#      16         async with session.get(url, params=params) as response:
# ---> 17             return await response.json()
#      18
#      19     async def run(self, brandID):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client_reqrep.py in json(self, encoding, loads, content_type)
#     728                     message=('Attempt to decode JSON with '
#     729                              'unexpected mimetype: %s' % ctype),
# --> 730                     headers=self.headers)
#     731
#     732         stripped = self._content.strip()
#
# ClientResponseError: 0, message='Attempt to decode JSON with unexpected mimetype: '

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[130:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 231
# Time Used: 6.482553958892822 sec
# Downloading brand 235
# Time Used: 0.6615869998931885 sec
# Downloading brand 236
# Time Used: 0.5822710990905762 sec
# Downloading brand 237
# Time Used: 2.4836478233337402 sec
# Downloading brand 239
# Time Used: 0.8990440368652344 sec
# Downloading brand 242
# Time Used: 1.1296370029449463 sec
# Downloading brand 244
# Time Used: 1.2698051929473877 sec
# Downloading brand 245
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-69-410137074441> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[137:150]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 245
# Time Used: 2.1249899864196777 sec
# Downloading brand 246
# Time Used: 2.4467570781707764 sec
# Downloading brand 250
# Time Used: 0.5765950679779053 sec
# Downloading brand 251
# Time Used: 3.8200600147247314 sec
# Downloading brand 252
# Time Used: 6.257076978683472 sec
# Downloading brand 253
# Time Used: 7.110929012298584 sec
# Downloading brand 254
# Time Used: 1.5426909923553467 sec
# Downloading brand 255
# Time Used: 0.966418981552124 sec
# Downloading brand 257
# Time Used: 1.2923610210418701 sec
# Downloading brand 261
# Time Used: 1.0700080394744873 sec
# Downloading brand 262
# Time Used: 1.1138818264007568 sec
# Downloading brand 263
# Time Used: 6.18603515625 sec
# Downloading brand 265
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-71-491728fd53d0> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[149:200]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
# Out:
# Downloading brand 265
# Time Used: 3.0920138359069824 sec
# Downloading brand 266
# Time Used: 2.4937760829925537 sec
# Downloading brand 267
# Time Used: 7.978736162185669 sec
# Downloading brand 268
# Time Used: 1.827200174331665 sec
# Downloading brand 269
# Time Used: 0.7564330101013184 sec
# Downloading brand 270
# Time Used: 0.6943340301513672 sec
# Downloading brand 273
# Time Used: 4.6215760707855225 sec
# Downloading brand 278
# Time Used: 0.4429450035095215 sec
# Downloading brand 280
# Time Used: 0.5866591930389404 sec
# Downloading brand 282
# Time Used: 0.4048941135406494 sec
# Downloading brand 283
# Time Used: 1.4913511276245117 sec
# Downloading brand 284
# Time Used: 4.9007649421691895 sec
# Downloading brand 286
# Time Used: 1.7615599632263184 sec
# Downloading brand 288
# Time Used: 1.060662031173706 sec
# Downloading brand 289
# Time Used: 1.8428900241851807 sec
# Downloading brand 290
# Time Used: 2.5054140090942383 sec
# Downloading brand 291
# Time Used: 3.4425721168518066 sec
# Downloading brand 292
# Time Used: 10.927501201629639 sec
# Downloading brand 293
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     697
# --> 698         hosts = yield from self._resolve_host(req.url.raw_host, req.port)
#     699         exc = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in _resolve_host(self, host, port)
#     668                 addrs = yield from \
# --> 669                     self._resolver.resolve(host, port, family=self._family)
#     670                 self._cached_hosts.add(key, addrs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/resolver.py in resolve(self, host, port, family)
#      30         infos = yield from self._loop.getaddrinfo(
# ---> 31             host, port, type=socket.SOCK_STREAM, family=family)
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/concurrent/futures/thread.py in run(self)
#      54         try:
# ---> 55             result = self.fn(*self.args, **self.kwargs)
#      56         except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-73-611689d4166d> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      14         """
#      15
# ---> 16         async with session.get(url, params=params) as response:
#      17             return await response.json()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in __aenter__(self)
#     601         @asyncio.coroutine
#     602         def __aenter__(self):
# --> 603             self._resp = yield from self._coro
#     604             return self._resp
#     605
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 8] Cannot connect to host api.shopstyle.com:80 ssl:False [nodename nor servname provided, or not known]

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[167:200]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
    time.sleep(5)
# Out:
# Downloading brand 293
# Time Used: 1.1523070335388184 sec
# Downloading brand 294
# Time Used: 0.9059901237487793 sec
# Downloading brand 295
# Time Used: 2.9952361583709717 sec
# Downloading brand 296
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# <ipython-input-75-972660d5abb5> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#       7     time.sleep(5)
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     237                 # We use the `send` method directly, because coroutines
#     238                 # don't have `__iter__` and `__next__` methods.
# --> 239                 result = coro.send(None)
#     240             else:
#     241                 result = coro.throw(exc)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      15
#      16         async with session.get(url, params=params) as response:
# ---> 17             return await response.json()
#      18
#      19     async def run(self, brandID):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client_reqrep.py in json(self, encoding, loads, content_type)
#     728                     message=('Attempt to decode JSON with '
#     729                              'unexpected mimetype: %s' % ctype),
# --> 730                     headers=self.headers)
#     731
#     732         stripped = self._content.strip()
#
# ClientResponseError: 0, message='Attempt to decode JSON with unexpected mimetype: '

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[170:200]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
    time.sleep(5)
# Out:
# Downloading brand 296
# Time Used: 4.959430932998657 sec
# Downloading brand 298
# Time Used: 6.839138984680176 sec
# Downloading brand 299
# Time Used: 0.5571999549865723 sec
# Downloading brand 300
# Time Used: 3.689012050628662 sec
# Downloading brand 301
# Time Used: 1.104248046875 sec
# Downloading brand 306
# Time Used: 0.6153090000152588 sec
# Downloading brand 307
# Time Used: 0.5112438201904297 sec
# Downloading brand 308
# Time Used: 1.020658016204834 sec
# Downloading brand 309
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# <ipython-input-77-dce7c28d3837> in <module>()
#       3     start = time.time()
#       4     print("Downloading brand " + str(brandID))
# ----> 5     df=downloading(brandID)
#       6     print('Time Used:', time.time()-start, 'sec')
#       7     time.sleep(5)
#
# <ipython-input-10-04abd3f2eeae> in downloading(brandID)
#       2         loop = asyncio.get_event_loop()
#       3         future = asyncio.ensure_future(product_scraper.run(brandID))
# ----> 4         loop.run_until_complete(future)
#       5         result = future.result()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/base_events.py in run_until_complete(self, future)
#     385             raise RuntimeError('Event loop stopped before Future completed.')
#     386
# --> 387         return future.result()
#     388
#     389     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     239                 result = coro.send(None)
#     240             else:
# --> 241                 result = coro.throw(exc)
#     242         except StopIteration as exc:
#     243             self.set_result(exc.value)
#
# <ipython-input-8-939cf287a92b> in run(self, brandID)
#      25             tasks = [asyncio.ensure_future(self._fetch(BASEURL, offset, session))
#      26                      for offset in offset_params]
# ---> 27             return await asyncio.gather(*tasks, return_exceptions=False)
#      28
#      29 ## Multiple brands is slower
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in __iter__(self)
#     359         if not self.done():
#     360             self._blocking = True
# --> 361             yield self  # This tells Task to wait for completion.
#     362         assert self.done(), "yield from wasn't used with future"
#     363         return self.result()  # May raise too.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _wakeup(self, future)
#     294     def _wakeup(self, future):
#     295         try:
# --> 296             future.result()
#     297         except Exception as exc:
#     298             # This may also be a cancellation.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/futures.py in result(self)
#     272             self._tb_logger = None
#     273         if self._exception is not None:
# --> 274             raise self._exception
#     275         return self._result
#     276
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/asyncio/tasks.py in _step(***failed resolving arguments***)
#     237                 # We use the `send` method directly, because coroutines
#     238                 # don't have `__iter__` and `__next__` methods.
# --> 239                 result = coro.send(None)
#     240             else:
#     241                 result = coro.throw(exc)
#
# <ipython-input-8-939cf287a92b> in _fetch(self, url, params, session)
#      15
#      16         async with session.get(url, params=params) as response:
# ---> 17             return await response.json()
#      18
#      19     async def run(self, brandID):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/aiohttp/client_reqrep.py in json(self, encoding, loads, content_type)
#     728                     message=('Attempt to decode JSON with '
#     729                              'unexpected mimetype: %s' % ctype),
# --> 730                     headers=self.headers)
#     731
#     732         stripped = self._content.strip()
#
# ClientResponseError: 0, message='Attempt to decode JSON with unexpected mimetype: '

# %%
PERIOD_OF_TIME = 5
for brandID in brand_ids[178:200]:
    start = time.time()
    print("Downloading brand " + str(brandID))
    df=downloading(brandID)
    print('Time Used:', time.time()-start, 'sec')
    time.sleep(5)

# %%
brand_ids.index('309')
# Out:
# 178

# %%
df_products=pd.read_csv("data/products_brand_Apr.csv", header=0)

# %%
len(df_products)
# Out:
# 124673

# %%
df_products.head()
# Out:
#   Product ID                                               Name  Price  \
# 0  685109155             7 For All Mankind Zip Front Mini Skirt  189.0
# 1  642153271           7 For All Mankind(R) Dojo Wide Leg Jeans  159.0
# 2  706495263  7 For All Mankind(R) Roxanne Faux Suede Stripe...  229.0
# 3  536353752   7 For All Mankind b(air) Ankle Knee Hole Skinny.  179.0
# 4  704320894              7 For All Mankind Roxanne Ankle Jean.  229.0
#
#   Currency Retailer ID Retailer Name Brand ID         Brand Name  \
# 0      USD         105       REVOLVE        3  7 For All Mankind
# 1      USD           1     Nordstrom        3  7 For All Mankind
# 2      USD           1     Nordstrom        3  7 For All Mankind
# 3      USD         105       REVOLVE        3  7 For All Mankind
# 4      USD         105       REVOLVE        3  7 For All Mankind
#
#                                          Description  \
# 0  7 For All Mankind Zip Front Mini Skirt in Navy...
# 1  Hand-distressed details add a lived-in look to...
# 2  Pink faux-suede tuxedo stripes highlight the s...
# 3  7 For All Mankind b(air) Ankle Knee Hole Skinn...
# 4  7 For All Mankind Roxanne Ankle Jean. - size 2...
#
#                                          image_small  \
# 0  https://img.shopstyle-cdn.com/pim/5e/39/5e39ed...
# 1  https://img.shopstyle-cdn.com/pim/ad/06/ad061f...
# 2  https://img.shopstyle-cdn.com/pim/d5/74/d574cf...
# 3  https://img.shopstyle-cdn.com/pim/c1/12/c112d3...
# 4  https://img.shopstyle-cdn.com/pim/bc/86/bc86eb...
#
#                  ...                  \
# 0                ...
# 1                ...
# 2                ...
# 3                ...
# 4                ...
#
#                                          image_Large  \
# 0  https://img.shopstyle-cdn.com/sim/5e/39/5e39ed...
# 1  https://img.shopstyle-cdn.com/sim/ad/06/ad061f...
# 2  https://img.shopstyle-cdn.com/sim/d5/74/d574cf...
# 3  https://img.shopstyle-cdn.com/sim/c1/12/c112d3...
# 4  https://img.shopstyle-cdn.com/sim/bc/86/bc86eb...
#
#                                    image_IPhoneSmall  \
# 0  https://img.shopstyle-cdn.com/mim/5e/39/5e39ed...
# 1  https://img.shopstyle-cdn.com/mim/ad/06/ad061f...
# 2  https://img.shopstyle-cdn.com/mim/d5/74/d574cf...
# 3  https://img.shopstyle-cdn.com/mim/c1/12/c112d3...
# 4  https://img.shopstyle-cdn.com/mim/bc/86/bc86eb...
#
#                                           image_Best  \
# 0  https://img.shopstyle-cdn.com/pim/5e/39/5e39ed...
# 1  https://img.shopstyle-cdn.com/pim/ad/06/ad061f...
# 2  https://img.shopstyle-cdn.com/pim/d5/74/d574cf...
# 3  https://img.shopstyle-cdn.com/pim/c1/12/c112d3...
# 4  https://img.shopstyle-cdn.com/pim/bc/86/bc86eb...
#
#                                       image_Original  \
# 0  https://img.shopstyle-cdn.com/pim/5e/39/5e39ed...
# 1  https://img.shopstyle-cdn.com/pim/ad/06/ad061f...
# 2  https://img.shopstyle-cdn.com/pim/d5/74/d574cf...
# 3  https://img.shopstyle-cdn.com/pim/c1/12/c112d3...
# 4  https://img.shopstyle-cdn.com/pim/bc/86/bc86eb...
#
#                                         image_IPhone Extract Date  \
# 0  https://img.shopstyle-cdn.com/mim/5e/39/5e39ed...   2017-11-04
# 1  https://img.shopstyle-cdn.com/mim/ad/06/ad061f...   2017-05-02
# 2  https://img.shopstyle-cdn.com/mim/d5/74/d574cf...   2018-01-21
# 3  https://img.shopstyle-cdn.com/mim/c1/12/c112d3...   2016-08-10
# 4  https://img.shopstyle-cdn.com/mim/bc/86/bc86eb...   2018-01-31
#
#   Last Modified                  Colors  \
# 0    2018-02-26                ['Navy']
# 1    2018-04-07                ['Blue']
# 2    2018-04-08                ['Blue']
# 3    2018-03-31               ['Black']
# 4    2018-04-06  ['Vintage Blue Dunes']
#
#                                                Sizes  \
# 0                                 ['27', '29', '30']
# 1  ['24', '25', '23', '26', '27', '28', '29', '31...
# 2         ['27', '24', '28', '32', '30', '29', '31']
# 3         ['24', '25', '26', '27', '28', '29', '30']
# 4                           ['26', '27', '28', '30']
#
#                           Categories
# 0                    ['Mini Skirts']
# 1               ['Distressed Denim']
# 2  ['Skinny Denim', 'Stretch Denim']
# 3                   ['Skinny Denim']
# 4                   ['Skinny Denim']
#
# [5 rows x 22 columns]

# %%
# delete the brands if len(products)<10
